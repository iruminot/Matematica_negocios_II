# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 4
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 warnings.filterwarnings("default")
#
# NameError: name 'warnings' is not defined

# %% [markdown]
# # Captilo I: Límites

# %% [markdown]
# Consideremos un intervalo abierto $I = (a,b)$, un punto $c \in \mathbb{R}$ y una función $f : I \backslash \{ c \} \longrightarrow \mathbb{R}$. Aunque $f$ no este definida en $c$ (pues $c$ no existe como preimagen de la función $f$ ya que no esta definida en su dominio, por lo tanto no existe la imagen $f(c)$), si se analiza el comportamiento de $f(x)$ para puntos $x \in I \backslash \{ c \}$ muy próximos a $c$, es posible que dichas imágenes se aproximen a un valor $L \in \mathbb{R}$

# %% [markdown]
# ### Ejemplo
# Estudiemos la siguiente función $f: (0,2) \backslash \{ 1 \} \longrightarrow \mathbb{R}$, definida por $f(x) = \dfrac{x^2 -1}{x-1}$.
#
# La siguiente tabla muestra algunas aproximaciones de la imagen $f(x)$ cuando $x$ es cercano a $1$, punto donde la función no esta definida.

# %%
def f(x):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        return np.where(x == 1, 2, (x**2 - 1)/(x - 1))

x = [0.9, 0.99, 0.999, 1, 1.001, 1.01, 1.1]
y = f(np.array(x))

df = pd.DataFrame({'x': x, 'f(x)': y})
df.head(101)
# Out:
# /var/folders/4w/js2qgjy52hqch0g1cczbv_sc0000gn/T/ipykernel_11821/1203290130.py:2: RuntimeWarning: invalid value encountered in divide
#   return np.where(x == 1, 2, (x**2 - 1)/(x - 1))
#        x   f(x)
# 0  0.900  1.900
# 1  0.990  1.990
# 2  0.999  1.999
# 3  1.000  2.000
# 4  1.001  2.001
# 5  1.010  2.010
# 6  1.100  2.100

# %%
plt.plot(x, y, color='blue', label='y =f(x)')
plt.scatter([1], [2], color='red', label='f(1)=2 ')
plt.title('Gráfica de f')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend()
plt.show()

# %%
def f(x):
    return np.sin(1/x)

x = np.linspace(-1/2, 1/2, 1000)
y = f(x)

plt.plot(x, y)
plt.title('Gráfica de f')
plt.xlabel('x')
plt.ylabel('f(x)')
# plt.xlim(0, 5)
# plt.ylim(0, 5)
plt.grid()
plt.show()

# %%
y=[]
for num in x:
    y.append(f(num))

df = pd.DataFrame({'x': x, 'f(x)': y})
df.head(100)
# Out:
#            x      f(x)
# 0   0.100000  1.100000
# 1   0.109091  1.109091
# 2   0.118182  1.118182
# 3   0.127273  1.127273
# 4   0.136364  1.136364
# ..       ...       ...
# 95  0.963635  1.963635
# 96  0.972726  1.972726
# 97  0.981817  1.981817
# 98  0.990908  1.990908
# 99  0.999999  1.999999
#
# [100 rows x 2 columns]

# %%
xn = []
for i in range(1, 51):
    xn.append(1/(i*np.pi))

yn = f(np.array(xn))

df_n = pd.DataFrame({'x': xn, 'f(x)': yn})
df_n.head(100)
# Out:
#            x          f(x)
# 0   0.318310  1.224647e-16
# 1   0.159155 -2.449294e-16
# 2   0.106103  3.673940e-16
# 3   0.079577 -4.898587e-16
# 4   0.063662  6.123234e-16
# 5   0.053052 -7.347881e-16
# 6   0.045473  8.572528e-16
# 7   0.039789 -9.797174e-16
# 8   0.035368  4.654896e-15
# 9   0.031831 -1.224647e-15
# 10  0.028937  4.899825e-15
# 11  0.026526 -1.469576e-15
# 12  0.024485 -1.960673e-15
# 13  0.022736 -1.714506e-15
# 14  0.021221  5.389684e-15
# 15  0.019894 -1.959435e-15
# 16  0.018724 -1.470814e-15
# 17  0.017684 -9.309792e-15
# 18  0.016753  5.879543e-15
# 19  0.015915 -2.449294e-15
# 20  0.015158 -9.809554e-16
# 21  0.014469 -9.799650e-15
# 22  0.013840  6.369401e-15
# 23  0.013263 -2.939152e-15
# 24  0.012732 -4.910967e-16
# 25  0.012243  3.921346e-15
# 26  0.011789  6.859260e-15
# 27  0.011368 -3.429011e-15
# 28  0.010976 -1.237961e-18
# 29  0.010610 -1.077937e-14
# 30  0.010268  2.155997e-14
# 31  0.009947 -3.918870e-15
# 32  0.009646  4.886208e-16
# 33  0.009362  2.941628e-15
# 34  0.009095  7.838977e-15
# 35  0.008842 -1.861958e-14
# 36  0.008603  9.784795e-16
# 37  0.008377 -1.175909e-14
# 38  0.008162  8.328836e-15
# 39  0.007958 -4.898587e-15
# 40  0.007764  1.567919e-14
# 41  0.007579  1.961911e-15
# 42  0.007403  8.818695e-15
# 43  0.007234 -1.959930e-14
# 44  0.007074  1.958197e-15
# 45  0.006920 -1.273880e-14
# 46  0.006773 -4.902301e-15
# 47  0.006631 -5.878305e-15
# 48  0.006496  1.665891e-14
# 49  0.006366  9.821934e-16

# %%
xn2 = []
for i in range(1, 51):
    xn2.append(1/(np.pi/2 +2*i*np.pi))

yn2 = f(np.array(xn2))

df_n2 = pd.DataFrame({'x': xn2, 'f(x)': yn2})
df_n2.head(100)
# Out:
#            x  f(x)
# 0   0.127324   1.0
# 1   0.070736   1.0
# 2   0.048971   1.0
# 3   0.037448   1.0
# 4   0.030315   1.0
# 5   0.025465   1.0
# 6   0.021952   1.0
# 7   0.019292   1.0
# 8   0.017206   1.0
# 9   0.015527   1.0
# 10  0.014147   1.0
# 11  0.012992   1.0
# 12  0.012012   1.0
# 13  0.011169   1.0
# 14  0.010436   1.0
# 15  0.009794   1.0
# 16  0.009226   1.0
# 17  0.008721   1.0
# 18  0.008268   1.0
# 19  0.007860   1.0
# 20  0.007490   1.0
# 21  0.007153   1.0
# 22  0.006845   1.0
# 23  0.006563   1.0
# 24  0.006303   1.0
# 25  0.006063   1.0
# 26  0.005841   1.0
# 27  0.005634   1.0
# 28  0.005441   1.0
# 29  0.005261   1.0
# 30  0.005093   1.0
# 31  0.004935   1.0
# 32  0.004787   1.0
# 33  0.004647   1.0
# 34  0.004515   1.0
# 35  0.004390   1.0
# 36  0.004273   1.0
# 37  0.004161   1.0
# 38  0.004055   1.0
# 39  0.003954   1.0
# 40  0.003858   1.0
# 41  0.003767   1.0
# 42  0.003680   1.0
# 43  0.003597   1.0
# 44  0.003517   1.0
# 45  0.003441   1.0
# 46  0.003368   1.0
# 47  0.003299   1.0
# 48  0.003232   1.0
# 49  0.003167   1.0
